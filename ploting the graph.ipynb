# %%
import numpy as np
import pandas as pd

# There are some fake data csv files
# you can read in as dataframes
df1 = pd.read_csv('FB.csv')
df2 = pd.read_csv('iris.csv')
df1['Low'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['Low'].hist()
# Out:
# <AxesSubplot:>

# %%
#plt.style.use('dark_background')
df1['Low'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['Low'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.scatter(x='Low', y='Volume')
# Out:
# <AxesSubplot:xlabel='Low', ylabel='Volume'>

# %%
df1.plot.scatter(x ='Low', y ='Volume', s = df1['High']*200)
# Out:
# <AxesSubplot:xlabel='Low', ylabel='Volume'>

# %%
df2['petal_length'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# df2.plot.area()

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
pie = pd.Series(np.random.rand(5))
pie
pie.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
