# %%
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv("student.csv")

# %%
dataset.head(5)
# Out:
#     name  roll no gender  age  maths  cs kannada  english  hindi  socila  \
# 0   jaya        1      f   21     98  99      89       99     60      72
# 1  kavya        2      f   22     87  44      76       89     61      73
# 2  navya        3      f   23     99  45      54       79     62      74
# 3  divya        4      f   24      7  64      56       69     63      75
# 4  sunil        5      m   24     78  54      75       59     64      76
#
#    science
# 0       78
# 1       79
# 2       80
# 3       81
# 4       82

# %%
dataset.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'roll no'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'maths'}>],
#        [<AxesSubplot:title={'center':'cs'}>,
#         <AxesSubplot:title={'center':'english'}>,
#         <AxesSubplot:title={'center':'hindi'}>],
#        [<AxesSubplot:title={'center':'socila'}>,
#         <AxesSubplot:title={'center':'science'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
dataset.describe(include="all")
# Out:
#          name    roll no gender        age      maths         cs kannada  \
# count      25  25.000000     25  25.000000  25.000000  25.000000      25
# unique     24        NaN      2        NaN        NaN        NaN      10
# top     kavya        NaN      f        NaN        NaN        NaN     nil
# freq        2        NaN     14        NaN        NaN        NaN       5
# mean      NaN  10.720000    NaN  30.360000  51.720000  64.800000     NaN
# std       NaN   7.294518    NaN   6.217449  28.813365  22.325247     NaN
# min       NaN   0.000000    NaN  21.000000   7.000000  15.000000     NaN
# 25%       NaN   5.000000    NaN  25.000000  21.000000  45.000000     NaN
# 50%       NaN   9.000000    NaN  29.000000  56.000000  67.000000     NaN
# 75%       NaN  17.000000    NaN  38.000000  76.000000  86.000000     NaN
# max       NaN  23.000000    NaN  38.000000  99.000000  99.000000     NaN
#
#            english      hindi     socila     science
# ...

# %%
dataset.tail(5)
# Out:
#         name  roll no gender  age  maths  cs kannada  english  hindi  socila  \
# 20      danu       19      m   38     21  90     nil     -101     80      92
# 21     namdu       20      m   38     45  68     nil     -111     81      93
# 22    shreyu       21      m   38     57  67     nil     -121     82      94
# 23    shreya       22      m   38     21  86     nil     -131     83      95
# 24  shereesh       23      m   38     75  86     nil     -141     84      96
#
#     science
# 20       98
# 21       99
# 22      100
# 23      101
# 24      102

# %%
sns.boxplot(x="roll no",y="english",data=dataset)
# Out:
# <AxesSubplot:xlabel='roll no', ylabel='english'>

# %%
duplicate_row_car=car[car]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4636/679487566.py in <module>
# ----> 1 duplicate_row_car=car[car]
#
# NameError: name 'car' is not defined

# %%
sns.pairplot(dataset)

# %%
dataset=dataset.drop_duplicates()
dataset.head()
# Out:
#     name  roll no gender  age  maths  cs kannada  english  hindi  socila  \
# 0   jaya        1      f   21     98  99      89       99     60      72
# 1  kavya        2      f   22     87  44      76       89     61      73
# 2  navya        3      f   23     99  45      54       79     62      74
# 3  divya        4      f   24      7  64      56       69     63      75
# 4  sunil        5      m   24     78  54      75       59     64      76
#
#    science
# 0       78
# 1       79
# 2       80
# 3       81
# 4       82

# %%
dataset.count()
# Out:
# name       25
# roll no    25
# gender     25
# age        25
# maths      25
# cs         25
# kannada    25
# english    25
# hindi      25
# socila     25
# science    25
# dtype: int64

# %%
duplicate_row_dataset=dataset[dataset.duplicated()]
print("Number of duplicate row:",duplicate_row_dataset.shape)
# Out:
# Number of duplicate row: (0, 11)
